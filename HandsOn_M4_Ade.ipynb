# %% [markdown]
# <a href="https://colab.research.google.com/github/Adesaputra4006/Analisis_Regresi/blob/main/HandsOn_M4_Ade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Analisis Regresi

# %% [markdown]
# ## **No 1**
# ### *Buat analisis korelasi lengkap. Muat dataset eksternal (misalnya, .csv) dengan beberapa variabel, pilih beberapa pasang variabel yang relevan, hitung koefisien korelasi Pearson untuk pasangan tersebut. Visualisasikan korelasi dengan scatterplot informatif (misalnya, dengan garis regresi). Lakukan uji hipotesis korelasi untuk korelasi terkuat dan berikan interpretasi mendalam mengenai jenis, kekuatan, signifikansi, implikasi praktis, serta batasan (termasuk korelasi vs. kausalitas) dari hasil analisis.*

# %%
from scipy.stats import pearsonr
from scipy.stats import linregress
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv("/content/Data No 1.csv")
print(df.head())

variabel_x = df["Pendapatan"]
variabel_y = df["Pengeluaran"]
print(variabel_x.head())
print(variabel_y.head())

# Hitung koefisien korelasi Pearson
korelasi_pearson, p_value = pearsonr(variabel_x, variabel_y)
print(f"\nKoefisien Korelasi Pearson antara Variabel X dan Variabel Y: {korelasi_pearson:.3f}")

# Interpretasi hasil
if korelasi_pearson > 0.8:
    interpretasi = "Korelasi sangat kuat positif"
elif korelasi_pearson > 0.6:
    interpretasi = "Korelasi kuat positif"
elif korelasi_pearson > 0.4:
    interpretasi = "Korelasi sedang positif"
elif korelasi_pearson > 0.2:
    interpretasi = "Korelasi lemah positif"
elif korelasi_pearson > 0:
    interpretasi = "Korelasi sangat lemah positif"
elif korelasi_pearson < -0.8:
    interpretasi = "Korelasi sangat kuat negatif"
elif korelasi_pearson < -0.6:
    interpretasi = "Korelasi kuat negatif"
elif korelasi_pearson < -0.4:
    interpretasi = "Korelasi sedang negatif"
elif korelasi_pearson < -0.2:
    interpretasi = "Korelasi lemah negatif"
elif korelasi_pearson < 0:
    interpretasi = "Korelasi sangat lemah negatif"
else:
    interpretasi = "Tidak ada korelasi linier (atau sangat mendekati nol)"

print(f"Interpretasi: {interpretasi}")

# Buat scatterplot

from scipy.stats import linregress

# Hitung parameter regresi linear
hasil_regresi = linregress(variabel_x, variabel_y)
slope = hasil_regresi.slope
intercept = hasil_regresi.intercept

# Buat prediksi Y berdasarkan garis regresi
y_pred = slope * variabel_x + intercept

# Plot scatter baru + garis regresi
plt.figure(figsize=(8, 6))
plt.scatter(variabel_x, variabel_y, label="Data Asli")
plt.plot(variabel_x, y_pred, color='red', linewidth=2, label="Garis Regresi")

plt.xlabel("Variabel X")
plt.ylabel("Variabel Y")
plt.title("Scatterplot dengan Garis Regresi Linear")
plt.legend()
plt.grid(True)
plt.show()

print("\nPersamaan regresi:")
print(f"Y = {intercept:.3f} + {slope:.3f}X")


# Hitung koefisien korelasi Pearson dan p-value
korelasi_pearson, p_value = pearsonr(variabel_x, variabel_y)
# Tetapkan tingkat signifikansi (alpha)
alpha = 0.05
print(f"Koefisien Korelasi Pearson: {korelasi_pearson:.3f}")
print(f"P-value: {p_value:.3f}")
print(f"Tingkat Signifikansi (alpha): {alpha}")
# Lakukan uji hipotesis
if p_value < alpha:
    keputusan = "Tolak Hipotesis Nol (H0)"
    interpretasi_uji = "Ada bukti statistik yang cukup untuk menyimpulkan adanya hubungan linier yang signifikan antara Variabel X dan Variabel Y dalam populasi."
else:
    keputusan = "Gagal Menolak Hipotesis Nol (H0)"
    interpretasi_uji = "Tidak ada bukti statistik yang cukup untuk menyimpulkan adanya hubungan linier yang signifikan antara Variabel X dan Variabel Y dalam populasi."
print(f"\nKeputusan: {keputusan}")
print(f"Interpretasi Uji: {interpretasi_uji}")


print('===============================================================')
print('Korelasi antara Pendapatan dan Tabungan')

variabel_x1 = df["Pendapatan"]
variabel_y2 = df["Tabungan"]
print(variabel_x1.head())
print(variabel_y2.head())

# Hitung koefisien korelasi Pearson
korelasi_pearson, p_value = pearsonr(variabel_x1, variabel_y2)
print(f"\nKoefisien Korelasi Pearson antara Variabel X1 dan Variabel Y2: {korelasi_pearson:.3f}")

# Interpretasi hasil
if korelasi_pearson > 0.8:
    interpretasi = "Korelasi sangat kuat positif"
elif korelasi_pearson > 0.6:
    interpretasi = "Korelasi kuat positif"
elif korelasi_pearson > 0.4:
    interpretasi = "Korelasi sedang positif"
elif korelasi_pearson > 0.2:
    interpretasi = "Korelasi lemah positif"
elif korelasi_pearson > 0:
    interpretasi = "Korelasi sangat lemah positif"
elif korelasi_pearson < -0.8:
    interpretasi = "Korelasi sangat kuat negatif"
elif korelasi_pearson < -0.6:
    interpretasi = "Korelasi kuat negatif"
elif korelasi_pearson < -0.4:
    interpretasi = "Korelasi sedang negatif"
elif korelasi_pearson < -0.2:
    interpretasi = "Korelasi lemah negatif"
elif korelasi_pearson < 0:
    interpretasi = "Korelasi sangat lemah negatif"
else:
    interpretasi = "Tidak ada korelasi linier (atau sangat mendekati nol)"

print(f"Interpretasi: {interpretasi}")

# Buat scatterplot
# Hitung parameter regresi linear
hasil_regresi = linregress(variabel_x1, variabel_y2)
slope = hasil_regresi.slope
intercept = hasil_regresi.intercept

# Buat prediksi Y berdasarkan garis regresi
y_pred = slope * variabel_x1 + intercept

# Plot scatter baru + garis regresi
plt.figure(figsize=(8, 6))
plt.scatter(variabel_x1, variabel_y2, label="Data Asli")
plt.plot(variabel_x1, y_pred, color='red', linewidth=2, label="Garis Regresi")

plt.xlabel("Variabel X1")
plt.ylabel("Variabel Y2")
plt.title("Scatterplot dengan Garis Regresi Linear")
plt.legend()
plt.grid(True)
plt.show()

print("\nPersamaan regresi:")
print(f"Y = {intercept:.3f} + {slope:.3f}X")


# Hitung koefisien korelasi Pearson dan p-value
korelasi_pearson, p_value = pearsonr(variabel_x, variabel_y)
# Tetapkan tingkat signifikansi (alpha)
alpha = 0.05
print(f"Koefisien Korelasi Pearson: {korelasi_pearson:.3f}")
print(f"P-value: {p_value:.3f}")
print(f"Tingkat Signifikansi (alpha): {alpha}")
# Lakukan uji hipotesis
if p_value < alpha:
    keputusan = "Tolak Hipotesis Nol (H0)"
    interpretasi_uji = "Ada bukti statistik yang cukup untuk menyimpulkan adanya hubungan linier yang signifikan antara Variabel X1 dan Variabel Y2 dalam populasi."
else:
    keputusan = "Gagal Menolak Hipotesis Nol (H0)"
    interpretasi_uji = "Tidak ada bukti statistik yang cukup untuk menyimpulkan adanya hubungan linier yang signifikan antara Variabel X1 dan Variabel Y2 dalam populasi."
print(f"\nKeputusan: {keputusan}")
print(f"Interpretasi Uji: {interpretasi_uji}")

# Mencari korelasi antar semua variabel
corr_matrix = df.corr(method='pearson')

print("Matrix Korelasi:")
print(corr_matrix)

# Cari nilai korelasi terbesar selain 1.0 (self-correlation)
corr_flat = corr_matrix.unstack()
corr_flat = corr_flat[corr_flat != 1]  # buang nilai diagonal
corr_terkuat = corr_flat.abs().idxmax()

print("\nKorelasi terkuat antara variabel:")
print(corr_terkuat)
print("Nilai:", corr_flat[corr_terkuat])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Pendapatan  Pengeluaran  Tabungan  Investasi
# 0     7596056      5137534   2434172    1018654
# 1     6834082      4661442   2188612    1001856
# 2     7777226      5069191   2920129    1139193
# 3     8827635      5934413   3084777    1324234
# 4     6719015      4575974   2239905     903541
# 0    7596056
# 1    6834082
# 2    7777226
# 3    8827635
# 4    6719015
# Name: Pendapatan, dtype: int64
# 0    5137534
# 1    4661442
# 2    5069191
# 3    5934413
# 4    4575974
# Name: Pengeluaran, dtype: int64
#
# Koefisien Korelasi Pearson antara Variabel X dan Variabel Y: 0.963
# Interpretasi: Korelasi sangat kuat positif
# Persamaan regresi:
# Y = 193962.024 + 0.646X
# Koefisien Korelasi Pearson: 0.963
# P-value: 0.000
# Tingkat Signifikansi (alpha): 0.05
#
# Keputusan: Tolak Hipotesis Nol (H0)
# Interpretasi Uji: Ada bukti statistik yang cukup untuk menyimpulkan adanya hubungan linier yang signifikan antara Variabel X dan Variabel Y dalam populasi.
# ===============================================================
# Korelasi antara Pendapatan dan Tabungan
# 0    7596056
# 1    6834082
# 2    7777226
# 3    8827635
# 4    6719015
# Name: Pendapatan, dtype: int64
# 0    2434172
# 1    2188612
# 2    2920129
# 3    3084777
# 4    2239905
# Name: Tabungan, dtype: int64
#
# Koefisien Korelasi Pearson antara Variabel X1 dan Variabel Y2: 0.851
# Interpretasi: Korelasi sangat kuat positif
# Persamaan regresi:
# Y = -55265.856 + 0.350X
# Koefisien Korelasi Pearson: 0.963
# P-value: 0.000
# Tingkat Signifikansi (alpha): 0.05
#
# Keputusan: Tolak Hipotesis Nol (H0)
# Interpretasi Uji: Ada bukti statistik yang cukup untuk menyimpulkan adanya hubungan linier yang signifikan antara Variabel X1 dan Variabel Y2 dalam populasi.
# Matrix Korelasi:
#              Pendapatan  Pengeluaran  Tabungan  Investasi
# Pendapatan     1.000000     0.963019  0.850595   0.767534
# Pengeluaran    0.963019     1.000000  0.703885   0.625328
# Tabungan       0.850595     0.703885  1.000000   0.918092
# Investasi      0.767534     0.625328  0.918092   1.000000
#
# Korelasi terkuat antara variabel:
# ('Pendapatan', 'Pengeluaran')
# Nilai: 0.9630186349514812

# %% [markdown]
# ## **No 2**
# ###Lakukan analisis korelasi lengkap dengan memuat dataset eksternal, memilih variabel, menghitung koefisien korelasi Pearson, memvisualisasikan dengan scatterplot dan garis regresi, melakukan uji hipotesis, dan memberikan interpretasi mendalam.

# %%
df = pd.read_csv("/content/Data No 2.csv")
print(df.head())

variabel_x = df["jam_penggunaan_per_hari"]
variabel_y = df["kualitas_tidur"]
print(variabel_x.head())
print(variabel_y.head())

# Hitung koefisien korelasi Pearson
korelasi_pearson, p_value = pearsonr(variabel_x, variabel_y)
print(f"\nKoefisien Korelasi Pearson antara Variabel X dan Variabel Y: {korelasi_pearson:.3f}")

# Interpretasi hasil
if korelasi_pearson > 0.8:
    interpretasi = "Korelasi sangat kuat positif"
elif korelasi_pearson > 0.6:
    interpretasi = "Korelasi kuat positif"
elif korelasi_pearson > 0.4:
    interpretasi = "Korelasi sedang positif"
elif korelasi_pearson > 0.2:
    interpretasi = "Korelasi lemah positif"
elif korelasi_pearson > 0:
    interpretasi = "Korelasi sangat lemah positif"
elif korelasi_pearson < -0.8:
    interpretasi = "Korelasi sangat kuat negatif"
elif korelasi_pearson < -0.6:
    interpretasi = "Korelasi kuat negatif"
elif korelasi_pearson < -0.4:
    interpretasi = "Korelasi sedang negatif"
elif korelasi_pearson < -0.2:
    interpretasi = "Korelasi lemah negatif"
elif korelasi_pearson < 0:
    interpretasi = "Korelasi sangat lemah negatif"
else:
    interpretasi = "Tidak ada korelasi linier (atau sangat mendekati nol)"

print(f"Interpretasi: {interpretasi}")

# Buat scatterplot
# Hitung parameter regresi linear
hasil_regresi = linregress(variabel_x, variabel_y)
slope = hasil_regresi.slope
intercept = hasil_regresi.intercept

# Buat prediksi Y berdasarkan garis regresi
y_pred = slope * variabel_x + intercept

# Plot scatter baru + garis regresi
plt.figure(figsize=(8, 6))
plt.scatter(variabel_x, variabel_y, label="Data Asli")
plt.plot(variabel_x, y_pred, color='red', linewidth=2, label="Garis Regresi")

plt.xlabel("Variabel X")
plt.ylabel("Variabel Y")
plt.title("Scatterplot dengan Garis Regresi Linear")
plt.legend()
plt.grid(True)
plt.show()

print("\nPersamaan regresi:")
print(f"Y = {intercept:.3f} + {slope:.3f}X")


# Hitung koefisien korelasi Pearson dan p-value
korelasi_pearson, p_value = pearsonr(variabel_x, variabel_y)
# Tetapkan tingkat signifikansi (alpha)
alpha = 0.05
print(f"Koefisien Korelasi Pearson: {korelasi_pearson:.3f}")
print(f"P-value: {p_value:.3f}")
print(f"Tingkat Signifikansi (alpha): {alpha}")
# Lakukan uji hipotesis
if p_value < alpha:
    keputusan = "Tolak Hipotesis Nol (H0)"
    interpretasi_uji = "Ada bukti statistik yang cukup untuk menyimpulkan adanya hubungan linier yang signifikan antara Variabel X dan Variabel Y dalam populasi."
else:
    keputusan = "Gagal Menolak Hipotesis Nol (H0)"
    interpretasi_uji = "Tidak ada bukti statistik yang cukup untuk menyimpulkan adanya hubungan linier yang signifikan antara Variabel X dan Variabel Y dalam populasi."
print(f"\nKeputusan: {keputusan}")
print(f"Interpretasi Uji: {interpretasi_uji}")
# Out:
#    jam_penggunaan_per_hari  tingkat_stres  kualitas_tidur  usia
# 0                      4.0              4               7    21
# 1                      8.6             10               3    19
# 2                      6.9             10               4    23
# 3                      5.8              8               5    23
# 4                      2.2              4               8    20
# 0    4.0
# 1    8.6
# 2    6.9
# 3    5.8
# 4    2.2
# Name: jam_penggunaan_per_hari, dtype: float64
# 0    7
# 1    3
# 2    4
# 3    5
# 4    8
# Name: kualitas_tidur, dtype: int64
#
# Koefisien Korelasi Pearson antara Variabel X dan Variabel Y: -0.923
# Interpretasi: Korelasi sangat kuat negatif
# Persamaan regresi:
# Y = 9.048 + -0.715X
# Koefisien Korelasi Pearson: -0.923
# P-value: 0.000
# Tingkat Signifikansi (alpha): 0.05
#
# Keputusan: Tolak Hipotesis Nol (H0)
# Interpretasi Uji: Ada bukti statistik yang cukup untuk menyimpulkan adanya hubungan linier yang signifikan antara Variabel X dan Variabel Y dalam populasi.
